# %%
import pandas as pd
from flask import jsonify

# %%
df = pd.read_html('http://www.pewhispanic.org/2017/02/13/estimates-of-unauthorized-immigrant-population-by-metro-area-2014/')

# %%
df = df[0]
df.head()
# Out:
#             Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                         Area\n              Total   Margin\nof error
# 0                   Total U.S.           11100000         +/-170,000
# 1                          NaN                NaN                NaN
# 2                    Akron, OH             <5,000           +/-3,000
# 3  Albany-Schenectady-Troy, NY             <5,000           +/-5,000
# 4              Albuquerque, NM              40000          +/-10,000
#
#   Unauthorized immigrant % of...\n Rank by population\n  \
#                  Foreign-born pop.          Total\npop.
# 0                             26.0                  3.5
# 1                              NaN                  NaN
# 2                             11.0                  0.4
# 3                              8.0                  0.6
# 4                             40.0                  4.3
#
#        Unnamed: 5_level_0 Unnamed: 6_level_0
# ...

# %%
df.dropna(inplace=True)
df.head()
# Out:
#                   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                               Area\n              Total   Margin\nof error
# 0                         Total U.S.           11100000         +/-170,000
# 2                          Akron, OH             <5,000           +/-3,000
# 3        Albany-Schenectady-Troy, NY             <5,000           +/-5,000
# 4                    Albuquerque, NM              40000          +/-10,000
# 5  Allentown-Bethlehem-Easton, PA-NJ              15000           +/-5,000
#
#   Unauthorized immigrant % of...\n Rank by population\n  \
#                  Foreign-born pop.          Total\npop.
# 0                             26.0                  3.5
# 2                             11.0                  0.4
# 3                              8.0                  0.6
# 4                             40.0                  4.3
# 5                             19.0                  1.7
#
# ...

# %%
[x for x in df.columns.get_level_values(1)]
# Out:
# ['Area\n',
#  'Total',
#  'Margin\nof error',
#  'Foreign-born pop.',
#  'Total\npop.',
#  'Unauthorized\nimmigrant',
#  'Total population\n']

# %%
df[[x for x in df.columns.get_level_values(0)]].head()
# Out:
#                   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                               Area\n              Total   Margin\nof error
# 0                         Total U.S.           11100000         +/-170,000
# 2                          Akron, OH             <5,000           +/-3,000
# 3        Albany-Schenectady-Troy, NY             <5,000           +/-5,000
# 4                    Albuquerque, NM              40000          +/-10,000
# 5  Allentown-Bethlehem-Easton, PA-NJ              15000           +/-5,000
#
#   Unauthorized immigrant % of...\n Rank by population\n  \
#                  Foreign-born pop.          Total\npop.
# 0                             26.0                  3.5
# 2                             11.0                  0.4
# 3                              8.0                  0.6
# 4                             40.0                  4.3
# 5                             19.0                  1.7
#
# ...

# %%
df.columns.droplevel()
# Out:
# Index(['Area\n', 'Total', 'Margin\nof error', 'Foreign-born pop.',
#        'Total\npop.', 'Unauthorized\nimmigrant', 'Total population\n'],
#       dtype='object')

# %%
df.columns = df.columns.droplevel()

# %%
df.to_dict()
# Out:
# {'Area\n': {0: 'Total U.S.',
#   2: 'Akron, OH',
#   3: 'Albany-Schenectady-Troy, NY',
#   4: 'Albuquerque, NM',
#   5: 'Allentown-Bethlehem-Easton, PA-NJ',
#   6: 'Amarillo, TX',
#   8: 'Anchorage, AK',
#   9: 'Ann Arbor, MI',
#   10: 'Asheville, NC',
#   11: 'Atlanta-Sandy Springs-Roswell, GA',
#   12: 'Atlantic City-Hammonton, NJ',
#   14: 'Augusta-Richmond County, GA-SC',
#   15: 'Austin-Round Rock, TX',
#   16: 'Bakersfield, CA',
#   17: 'Baltimore-Columbia-Towson, MD',
#   18: 'Baton Rouge, LA',
#   20: 'Beaumont-Port Arthur, TX',
#   21: 'Bellingham, WA',
#   22: 'Birmingham-Hoover, AL',
#   23: 'Boise City, ID',
#   24: 'Boston-Cambridge-Newton, MA-NH',
#   26: 'Bridgeport-Stamford-Norwalk, CT',
#   27: 'Brownsville-Harlingen, TX',
#   28: 'Buffalo-Cheektowaga-Niagara Falls, NY',
#   29: 'Cape Coral-Fort Myers, FL',
#   30: 'Champaign-Urbana, IL',
#   32: 'Charleston-North Charleston, SC',
#   33: 'Charlotte-Concord-Gastonia, NC-SC',
#   34: 'Chattanooga, TN-GA',
# ...
